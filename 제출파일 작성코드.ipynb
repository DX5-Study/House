# %% [markdown]
# # 아래 코드를 복사해서 이름_예측결과.csv 파일을 보내주세요

# %%
final = model.predict(test)  # test.csv 원본

submission = pd.read_csv('https://github.com/DX5-Study/House/raw/main/sample_submission.csv')
submission['SalePrice'] = final

submission.to_csv('이름_예측결과.csv')
